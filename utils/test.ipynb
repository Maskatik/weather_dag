# %%
from api_calls import get_data
import pandas as pd

# %%
df = get_data()
# Out:
# City: Almaty
# Latitude: 43.2363924, Longitude: 76.9457275
# Coordinates: 43.268890380859375°N 76.95066833496094°E
# Elevation: 887.0 m asl
# Timezone: b'Asia/Singapore'b'GMT+8'
# Timezone difference to GMT+0: 28800s

# %%
df
# Out:
#                         date  temperature_2m  weather_code  \
# 0  2026-04-12 00:00:00+00:00        9.809500           3.0
# 1  2026-04-12 01:00:00+00:00        8.909500           3.0
# 2  2026-04-12 02:00:00+00:00        8.359500           3.0
# 3  2026-04-12 03:00:00+00:00        7.509500           2.0
# 4  2026-04-12 04:00:00+00:00        6.659500           2.0
# 5  2026-04-12 05:00:00+00:00        6.459500           1.0
# 6  2026-04-12 06:00:00+00:00        5.959500           1.0
# 7  2026-04-12 07:00:00+00:00        5.509500           1.0
# 8  2026-04-12 08:00:00+00:00        5.309500           0.0
# 9  2026-04-12 09:00:00+00:00        5.809500           0.0
# 10 2026-04-12 10:00:00+00:00        9.009500           0.0
# 11 2026-04-12 11:00:00+00:00       11.259500           0.0
# 12 2026-04-12 12:00:00+00:00       12.959500           0.0
# 13 2026-04-12 13:00:00+00:00       14.959500           0.0
# 14 2026-04-12 14:00:00+00:00       16.509501           0.0
# ...
